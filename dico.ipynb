# %%
#http://www.python-simple.com/python-langage/tuple.php
alpha=[chr(i) for i in range(ord("a"),ord("z")+1)]
Alpha=[chr(i) for i in range(ord("A"),ord("Z")+1)]
print (alpha[:8],Alpha[:8])

a=tuple(x  for x in alpha[:4])
A=tuple(x  for x in Alpha[:4])
#affectation de vaviables  
v1,v2,v3,v4=A
print (v1)

(x, y, z) = (3,2,1)
print(x)

t="a","b","c"
x,y,z=t
print (x)
# Out:
# ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h'] ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H']
# A
# 3
# a

# %%
(x, y, z) = (3,2,1)
print (x)
t="a","b","c"
x,y,z=t
print (t,x)

myList = [(1, 2), (3, 4), (5, 6)]
for (x, y) in myList:
    print (x,y)
# Out:
# 3
# ('a', 'b', 'c') a
# 1 2
# 3 4
# 5 6

# %%
tuple(x ** 2 for x in [1, 2, 3, 4])
# Out:
# (1, 4, 9, 16)

# %%
u=[] # liste de dico
y={}
for i in "aeiouy":
  t={}
  t[i]=alpha.index(i)
  u.append(t)
print (u)
print (u[1],u[1].keys(),u[1].values())

for k,v in u[1].items():
  print ( k,v)
# Out:
# [{'a': 0}, {'e': 4}, {'i': 8}, {'o': 14}, {'u': 20}, {'y': 24}]
# {'e': 4} dict_keys(['e']) dict_values([4])
# e 4

# %%
u=[] # liste de tuple

for i in "aeiouy":
  t=()
  t=(i,i.upper())
  u.append(t)
print (u)
print(u[1][0])
# Out:
# [('a', 'A'), ('e', 'E'), ('i', 'I'), ('o', 'O'), ('u', 'U'), ('y', 'Y')]
# e

# %%
from array import array as table
a = table('d', [2.3, 5.4, 3.2, 2.7]) 
print (a.tolist())
a.extend([2.1, 8.3]) 
print (a)
a.append(5.3)
# Out:
# [2.3, 5.4, 3.2, 2.7]
# array('d', [2.3, 5.4, 3.2, 2.7, 2.1, 8.3])

# %%
o=[i for i in range(9)]
st=3
for i in o:
  h=i % st
  v= i // st
  if not h :print()
  print (h,v)
# Out:
# 0 0
# 1 0
# 2 0
#
# 0 1
# 1 1
# 2 1
#
# 0 2
# 1 2
# 2 2
