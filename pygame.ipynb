# %%
import pygame

# %%
# !ls
# Out:
# sample_data

# %%
# !pip install pygame
# Out:
# ...
#      |████████████████████████████████| 11.4MB 2.8MB/s
# ...

# %%
import os
os.environ['SDL_VIDEODRIVER']='dummy'
import pygame
pygame.display.set_mode((640,480))
# Out:
# <Surface(640x480x8 SW)>

# %%
pygame.init()
pygame.display.list_modes()
screen=pygame.display.set_mode([300, 200])
pygame.display.set_caption('Basic Pygame program')


pygame.draw.rect(screen, [255,0,0 ], [0, 0, 12, 12])
#pygame.display.update()
pygame.display.flip()

# %%
import matplotlib.pyplot as plt

# %%
circle1 = plt.Circle((0, 0), 0.2, color='r')
circle2 = plt.Circle((0.5, 0.5), 0.2, color='blue')
circle3 = plt.Circle((1, 1), 0.2, color='g', clip_on=False)

# %%
fig, ax = plt.subplots() 
ax.add_artist(circle1)
ax.add_artist(circle2)
ax.add_artist(circle3)

# %%
circle1 = plt.Circle((0, 0), 2, color='r')
# now make a circle with no fill, which is good for hi-lighting key results
circle2 = plt.Circle((5, 5), 0.5, color='b', fill=False)
circle3 = plt.Circle((10, 10), 2, color='g', clip_on=False)

#ax = plt.gca()
#ax.cla() # clear things for fresh plot

# change default range so that new circles will work

# %%
ax.cla() # clear things for fresh plot

ax = plt.gca()

ax.set_xlim((0, 15))
ax.set_ylim((0, 15))
# some data
ax.plot(range(11), 'o', color='black')
# key data point that we are encircling
ax.plot((5), (5), 'o', color='y')

ax.add_artist(circle1)
ax.add_artist(circle2)
ax.add_artist(circle3)

# %%
mat = [[0.5, 0.5, 1], [0, 1, 1], [0, 1, 1]]; plt.matshow(mat); plt.gray(); plt.show()

# %%
import pandas as pd
url = 'https://fred.stlouisfed.org/graph/fredgraph.csv?id=VIXCLS'
vix = pd.read_csv(url, index_col=0, parse_dates=True, na_values='.',infer_datetime_format=True,squeeze=True).dropna()

# %%
ma = vix.rolling('90d').mean()

# %%
import numpy as np
state = pd.cut(ma, bins=[-np.inf, 14, 18, 24, np.inf], labels=range(4))

# %%
cmap = plt.get_cmap('RdYlGn_r')

# %%
ma.plot(color='black', linewidth=1.5, marker='', figsize=(8, 4), label='VIX 90d MA')
ax.set_xlim(xmin=ma.index[0], xmax=ma.index[-1])
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_base.py:3215: MatplotlibDeprecationWarning:
# The `xmin` argument was deprecated in Matplotlib 3.0 and will be removed in 3.2. Use `left` instead.
#   alternative='`left`', obj_type='argument')
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_base.py:3221: MatplotlibDeprecationWarning:
# The `xmax` argument was deprecated in Matplotlib 3.0 and will be removed in 3.2. Use `right` instead.
#   alternative='`right`', obj_type='argument')
# (726469.0, 737220.0)

# %%
import matplotlib.transforms as mt

# %%
trans = mt.blended_transform_factory(ax.transData, ax.transAxes)

# %%
ax = plt.gca()  
#ax.set_xlim(xmin=ma.index[0], xmax=ma.index[-1])
ax.axhline(vix.mean(), linestyle='dashed', color='xkcd:dark grey',alpha=0.6, label='Full-period mean', marker='')
for i, color in enumerate(cmap([0.2, 0.4, 0.6, 0.8])):
  ax.fill_between(ma.index, 0, 1, where=state==i,facecolor=color, transform=trans)

# %%
lon=1000
ts = pd.Series(np.random.randn(lon), index=pd.date_range('1/1/2000', periods=lon)) 
ts = ts.cumsum()

ts.plot()

# %%
df = pd.DataFrame(np.random.randn(100, 3),  columns=list('ABC'))
df = df.cumsum()
plt.figure();
df.plot();

# %%
df3 = pd.DataFrame(np.random.randn(1000, 2), columns=['B', 'C']).cumsum()

df3['A'] = pd.Series(list(range(len(df))))

df3.plot(x='A', y='B')

# %%
plt.figure()
df = pd.DataFrame(np.random.randn(1000, 5),  columns=list('ABCDE'))

df.iloc[5].plot(kind='bar');

# %%
df = pd.DataFrame(np.random.randn(50,3),  columns=list('ABC'))

df.plot(subplots=True, figsize=(8, 6))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f8fcfd9ab70>,
# ...
#       dtype=object)

# %%
df.plot(subplots=True, layout=(1,3), figsize=(12, 4), sharex=False)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f8fcba17908>,
# ...
#       dtype=object)

# %%
fig, ax = plt.subplots(1, 1)
plt.figure()

df = pd.DataFrame(np.random.rand(5, 3), columns=['a', 'b', 'c'])
ax.get_xaxis().set_visible(False)
df.plot(table=True, ax=ax)
df.plot(table=np.round(df.T, 3), ax=ax)

# %%
#[(x,y) for x in range(5) for y in range(5)]
import random
matrix = [[j for j in range(5)] for i in range(5)] 
matrix
matrix = [[random.randint(-6,8) for j in range(5)] for i in range(5)] 
matrix
# Out:
# [[4, 8, -1, -4, -3],
#  [-5, 6, 3, -6, 7],
#  [-4, 1, 2, -6, 7],
#  [0, 1, 7, 8, 2],
#  [1, 7, 3, 2, -1]]

# %%
#df.plot(colormap='cubehelix')
plt.matshow(matrix,cmap='cubehelix')

# %%
plt.matshow(matrix,cmap='gist_rainbow')

# %%
plt.matshow(matrix,cmap='Greens')

# %%
plt.matshow(matrix,cmap='winter')

# %%
plt.matshow(matrix,cmap='YlOrRd')

# %%
plt.style.use('ggplot')
df = pd.DataFrame(np.random.randn(1000, 4), index=ts.index, columns=list('ABCD'))
df.iloc[5].plot(kind='bar'); plt.axhline(0, color='k')

# %%
df2 = pd.DataFrame(np.random.rand(10, 4), columns=['a', 'b', 'c', 'd'])
df2.plot.bar(stacked=True)
